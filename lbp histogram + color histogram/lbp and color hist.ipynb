# %%
import cv2
from skimage.feature import local_binary_pattern
import matplotlib.pyplot as plt
from cuml.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import os
from tqdm import tqdm 
import numpy as np
from cuml.ensemble import RandomForestClassifier

# %%
def get_lbp(img_path, radius=1, n_points=8, method='ror'):
    image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    image=cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
    lbp = local_binary_pattern(image, P=n_points, R=radius, method=method)
    return lbp

# %%
def get_histogram(img_path,bins=[8,4,2]):
    img=cv2.imread(img_path)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, bins,[0, 180, 0, 256, 0, 256])
    cv2.normalize(hist, hist)
    return hist.flatten()

# %%
import cv2
import numpy as np
from skimage.feature import local_binary_pattern

def get_lbp(img_path, grid_size=3, target_size=224):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (target_size, target_size))
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Tính LBP
    lbp = local_binary_pattern(gray, P=8, R=1, method='uniform')
    
    h, w = lbp.shape
    bin_h = h // grid_size
    bin_w = w // grid_size
    
    features = []
    for i in range(grid_size):
        for j in range(grid_size):
            # Lấy ô con
            patch = lbp[i*bin_h:(i+1)*bin_h, j*bin_w:(j+1)*bin_w]
            # Tính histogram cho ô này
            hist, _ = np.histogram(patch.ravel(), bins=256, range=(0, 256), density=True)
            features.append(hist)
    
    return np.concatenate(features)  # shape: (grid_size*grid_size*10,)

# %%
len(get_lbp("/kaggle/input/hath-food/food dataset/Images/train/Banh canh/1.jpg"))
# Out:
# 2304

# %%
BASE_PATH = "/kaggle/input/hath-food/food dataset/Images"

# %%
def load_dataset(root_path, subset="train"):

    data = []
    labels = []
    
    path = os.path.join(root_path, subset)
    if not os.path.exists(path):
        print(f"error in finding {path}")
        return np.array([]), np.array([])

    print(f"loading {subset}...")
    
    classes = os.listdir(path)
    
    for class_name in classes:
        class_dir = os.path.join(path, class_name)
        if not os.path.isdir(class_dir):
            continue
            
      
        files = os.listdir(class_dir)
        for file in tqdm(files, desc=class_name, leave=False):
            image_path = os.path.join(class_dir, file)
            
            hist = get_lbp(image_path)
            color_hist=get_histogram(image_path)
            if hist is not None:
                data.append(np.concatenate((hist,color_hist)))
                labels.append(class_name)
                
    return np.array(data), np.array(labels)

# %%
X_train, y_train_text = load_dataset(BASE_PATH, "train")
X_test, y_test_text = load_dataset(BASE_PATH, "test")
# Out:
# loading train...
# Goi cuon:  49%|████▉     | 296/598 [00:09<00:14, 20.85it/s]        Corrupt JPEG data: 229 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 229 extraneous bytes before marker 0xd9
# Nem chua:  22%|██▏       | 84/379 [00:02<00:12, 23.04it/s]  Corrupt JPEG data: 9 extraneous bytes before marker 0xe2
# Corrupt JPEG data: 9 extraneous bytes before marker 0xe2
# loading test...

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train_text)
y_test = le.transform(y_test_text)

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf', C=10.0, gamma='scale', random_state=42, cache_size=100)
model.fit(X_train, y_train)
# Out:
# SVC(C=10.0, cache_size=100, random_state=42)

# %%
y_pred = model.predict(X_test)

acc = accuracy_score(y_test, y_pred)

# %%
print(acc)
# Out:
# 0.2859126984126984

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import numpy as np
print("Độ chính xác (và các metric) theo từng lớp:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Độ chính xác (và các metric) theo từng lớp:
#                   precision    recall  f1-score   support
#
#         Banh beo       0.22      0.23      0.23       129
#     Banh bot loc       0.18      0.10      0.13       144
#         Banh can       0.26      0.21      0.23       149
#        Banh canh       0.15      0.10      0.12       193
#       Banh chung       0.42      0.34      0.38       102
#        Banh cuon       0.27      0.38      0.32       228
#         Banh duc       0.17      0.09      0.12       133
#         Banh gio       0.37      0.29      0.32       129
#        Banh khot       0.24      0.21      0.22       167
#          Banh mi       0.31      0.44      0.36       268
#         Banh pia       0.42      0.31      0.36        89
#         Banh tet       0.32      0.25      0.28       138
# Banh trang nuong       0.33      0.40      0.36       159
#         Banh xeo       0.45      0.55      0.49       235
#       Bun bo Hue       0.21      0.36      0.27       306
#  Bun dau mam tom       0.26      0.39      0.31       184
#          Bun mam       0.26      0.14      0.18       155
#         Bun rieu       0.25      0.35      0.29       231
#   Bun thit nuong       0.18      0.08      0.11       150
#        Ca kho to       0.41      0.48      0.44       136
#        Canh chua       0.29      0.19      0.23       165
#          Cao lau       0.18      0.08      0.11       124
#        Chao long       0.30      0.40      0.34       215
#          Com tam       0.26      0.29      0.27       189
#         Goi cuon       0.24      0.24      0.24       172
#          Hu tieu       0.25      0.21      0.23       197
#         Mi quang       0.27      0.18      0.21       177
#         Nem chua       0.48      0.33      0.39       109
#              Pho       0.31      0.28      0.30       162
#          Xoi xeo       0.45      0.29      0.35       105
#
#         accuracy                           0.29      5040
#        macro avg       0.29      0.27      0.27      5040
#     weighted avg       0.28      0.29      0.28      5040

# %%
import joblib
joblib.dump(model, 'svm_lbp_model.joblib')
# Out:
# ['svm_lbp_model.joblib']

# %%
classifier = RandomForestClassifier(n_estimators=500,min_samples_split=2,min_samples_leaf=2,max_depth=40)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import numpy as np
print("Độ chính xác (và các metric) theo từng lớp:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Độ chính xác (và các metric) theo từng lớp:
#                   precision    recall  f1-score   support
#
#         Banh beo       0.94      0.12      0.22       129
#     Banh bot loc       0.67      0.03      0.05       144
#         Banh can       0.53      0.07      0.12       149
#        Banh canh       0.21      0.06      0.09       193
#       Banh chung       0.72      0.23      0.34       102
#        Banh cuon       0.19      0.31      0.24       228
#         Banh duc       0.00      0.00      0.00       133
#         Banh gio       0.44      0.09      0.14       129
#        Banh khot       0.53      0.05      0.10       167
#          Banh mi       0.20      0.57      0.30       268
#         Banh pia       0.39      0.31      0.35        89
#         Banh tet       0.33      0.12      0.18       138
# Banh trang nuong       0.47      0.18      0.26       159
#         Banh xeo       0.27      0.60      0.37       235
#       Bun bo Hue       0.12      0.64      0.20       306
#  Bun dau mam tom       0.23      0.40      0.29       184
#          Bun mam       0.33      0.04      0.07       155
#         Bun rieu       0.16      0.11      0.13       231
#   Bun thit nuong       0.00      0.00      0.00       150
#        Ca kho to       0.48      0.17      0.25       136
#        Canh chua       0.30      0.13      0.18       165
#          Cao lau       0.33      0.01      0.02       124
#        Chao long       0.24      0.36      0.29       215
#          Com tam       0.36      0.09      0.14       189
#         Goi cuon       0.24      0.17      0.20       172
#          Hu tieu       0.24      0.20      0.22       197
#         Mi quang       0.38      0.09      0.15       177
#         Nem chua       0.71      0.09      0.16       109
#              Pho       0.33      0.08      0.13       162
#          Xoi xeo       0.26      0.06      0.09       105
#
#         accuracy                           0.21      5040
#        macro avg       0.35      0.18      0.18      5040
#     weighted avg       0.32      0.21      0.18      5040
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import joblib
joblib.dump(model, 'random_forest_lbp_model.joblib')
# Out:
# ['random_forest_lbp_model.joblib']

# %%
import xgboost as xgb
from sklearn.metrics import classification_report

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {
    'objective': 'multi:softmax', # trả về class trực tiếp
    'num_class': 30,
    'learning_rate': 0.1,
    'max_depth': 6,
    'eval_metric': 'mlogloss',
}

bst = xgb.train(params, dtrain, num_boost_round=300, evals=[(dtest, 'test')], early_stopping_rounds=10)

# Predict
y_pred = bst.predict(dtest)

# Report chi tiết theo class
print("Độ chính xác (và các metric) theo từng lớp:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# [0]	test-mlogloss:3.31900
# [1]	test-mlogloss:3.25739
# [2]	test-mlogloss:3.20686
# [3]	test-mlogloss:3.16242
# [4]	test-mlogloss:3.12241
# [5]	test-mlogloss:3.08527
# [6]	test-mlogloss:3.05324
# [7]	test-mlogloss:3.02250
# [8]	test-mlogloss:2.99486
# [9]	test-mlogloss:2.96914
# [10]	test-mlogloss:2.94619
# [11]	test-mlogloss:2.92414
# [12]	test-mlogloss:2.90409
# [13]	test-mlogloss:2.88442
# [14]	test-mlogloss:2.86536
# [15]	test-mlogloss:2.84740
# [16]	test-mlogloss:2.83270
# [17]	test-mlogloss:2.81781
# [18]	test-mlogloss:2.80408
# [19]	test-mlogloss:2.79139
# [20]	test-mlogloss:2.77898
# [21]	test-mlogloss:2.76576
# [22]	test-mlogloss:2.75432
# [23]	test-mlogloss:2.74338
# [24]	test-mlogloss:2.73353
# [25]	test-mlogloss:2.72477
# [26]	test-mlogloss:2.71620
# [27]	test-mlogloss:2.70746
# [28]	test-mlogloss:2.69864
# [29]	test-mlogloss:2.69028
# [30]	test-mlogloss:2.68277
# [31]	test-mlogloss:2.67547
# [32]	test-mlogloss:2.66851
# [33]	test-mlogloss:2.66228
# [34]	test-mlogloss:2.65591
# [35]	test-mlogloss:2.64975
# [36]	test-mlogloss:2.64351
# [37]	test-mlogloss:2.63827
# [38]	test-mlogloss:2.63264
# [39]	test-mlogloss:2.62773
# [40]	test-mlogloss:2.62193
# [41]	test-mlogloss:2.61627
# [42]	test-mlogloss:2.61142
# [43]	test-mlogloss:2.60722
# [44]	test-mlogloss:2.60251
# [45]	test-mlogloss:2.59762
# [46]	test-mlogloss:2.59366
# [47]	test-mlogloss:2.58923
# [48]	test-mlogloss:2.58540
# [49]	test-mlogloss:2.58212
# [50]	test-mlogloss:2.57819
# [51]	test-mlogloss:2.57426
# [52]	test-mlogloss:2.57086
# [53]	test-mlogloss:2.56841
# [54]	test-mlogloss:2.56493
# [55]	test-mlogloss:2.56149
# [56]	test-mlogloss:2.55822
# [57]	test-mlogloss:2.55572
# [58]	test-mlogloss:2.55280
# [59]	test-mlogloss:2.55039
# [60]	test-mlogloss:2.54773
# [61]	test-mlogloss:2.54595
# [62]	test-mlogloss:2.54379
# [63]	test-mlogloss:2.54129
# [64]	test-mlogloss:2.53894
# [65]	test-mlogloss:2.53639
# [66]	test-mlogloss:2.53410
# [67]	test-mlogloss:2.53237
# [68]	test-mlogloss:2.53065
# [69]	test-mlogloss:2.52902
# [70]	test-mlogloss:2.52722
# [71]	test-mlogloss:2.52531
# [72]	test-mlogloss:2.52361
# [73]	test-mlogloss:2.52189
# [74]	test-mlogloss:2.52016
# [75]	test-mlogloss:2.51880
# [76]	test-mlogloss:2.51700
# [77]	test-mlogloss:2.51578
# [78]	test-mlogloss:2.51385
# [79]	test-mlogloss:2.51269
# [80]	test-mlogloss:2.51098
# [81]	test-mlogloss:2.50933
# [82]	test-mlogloss:2.50762
# [83]	test-mlogloss:2.50585
# [84]	test-mlogloss:2.50471
# [85]	test-mlogloss:2.50319
# [86]	test-mlogloss:2.50174
# [87]	test-mlogloss:2.50044
# [88]	test-mlogloss:2.49967
# [89]	test-mlogloss:2.49866
# [90]	test-mlogloss:2.49752
# [91]	test-mlogloss:2.49609
# [92]	test-mlogloss:2.49493
# [93]	test-mlogloss:2.49372
# [94]	test-mlogloss:2.49294
# [95]	test-mlogloss:2.49115
# [96]	test-mlogloss:2.49057
# [97]	test-mlogloss:2.48907
# [98]	test-mlogloss:2.48831
# [99]	test-mlogloss:2.48698
# [100]	test-mlogloss:2.48602
# [101]	test-mlogloss:2.48494
# [102]	test-mlogloss:2.48423
# [103]	test-mlogloss:2.48308
# [104]	test-mlogloss:2.48220
# [105]	test-mlogloss:2.48142
# [106]	test-mlogloss:2.48042
# [107]	test-mlogloss:2.47975
# [108]	test-mlogloss:2.47886
# [109]	test-mlogloss:2.47801
# [110]	test-mlogloss:2.47721
# [111]	test-mlogloss:2.47655
# [112]	test-mlogloss:2.47523
# [113]	test-mlogloss:2.47481
# [114]	test-mlogloss:2.47442
# [115]	test-mlogloss:2.47315
# [116]	test-mlogloss:2.47217
# [117]	test-mlogloss:2.47155
# [118]	test-mlogloss:2.47053
# [119]	test-mlogloss:2.46965
# [120]	test-mlogloss:2.46889
# [121]	test-mlogloss:2.46846
# [122]	test-mlogloss:2.46743
# [123]	test-mlogloss:2.46701
# [124]	test-mlogloss:2.46673
# [125]	test-mlogloss:2.46636
# [126]	test-mlogloss:2.46598
# [127]	test-mlogloss:2.46529
# [128]	test-mlogloss:2.46433
# [129]	test-mlogloss:2.46435
# [130]	test-mlogloss:2.46351
# [131]	test-mlogloss:2.46300
# [132]	test-mlogloss:2.46258
# [133]	test-mlogloss:2.46172
# [134]	test-mlogloss:2.46150
# [135]	test-mlogloss:2.46103
# [136]	test-mlogloss:2.46094
# [137]	test-mlogloss:2.46059
# [138]	test-mlogloss:2.46026
# [139]	test-mlogloss:2.45991
# [140]	test-mlogloss:2.45973
# [141]	test-mlogloss:2.45946
# [142]	test-mlogloss:2.45911
# [143]	test-mlogloss:2.45874
# [144]	test-mlogloss:2.45832
# [145]	test-mlogloss:2.45806
# [146]	test-mlogloss:2.45717
# [147]	test-mlogloss:2.45655
# [148]	test-mlogloss:2.45670
# [149]	test-mlogloss:2.45662
# [150]	test-mlogloss:2.45628
# [151]	test-mlogloss:2.45621
# [152]	test-mlogloss:2.45561
# [153]	test-mlogloss:2.45534
# [154]	test-mlogloss:2.45523
# [155]	test-mlogloss:2.45480
# [156]	test-mlogloss:2.45463
# [157]	test-mlogloss:2.45490
# [158]	test-mlogloss:2.45425
# [159]	test-mlogloss:2.45404
# [160]	test-mlogloss:2.45376
# [161]	test-mlogloss:2.45355
# [162]	test-mlogloss:2.45346
# [163]	test-mlogloss:2.45302
# [164]	test-mlogloss:2.45297
# [165]	test-mlogloss:2.45255
# [166]	test-mlogloss:2.45236
# [167]	test-mlogloss:2.45240
# [168]	test-mlogloss:2.45199
# [169]	test-mlogloss:2.45167
# [170]	test-mlogloss:2.45173
# [171]	test-mlogloss:2.45158
# [172]	test-mlogloss:2.45121
# [173]	test-mlogloss:2.45143
# [174]	test-mlogloss:2.45121
# [175]	test-mlogloss:2.45123
# [176]	test-mlogloss:2.45114
# [177]	test-mlogloss:2.45103
# [178]	test-mlogloss:2.45062
# [179]	test-mlogloss:2.45046
# [180]	test-mlogloss:2.45010
# [181]	test-mlogloss:2.45051
# [182]	test-mlogloss:2.45034
# [183]	test-mlogloss:2.45025
# [184]	test-mlogloss:2.45029
# [185]	test-mlogloss:2.45048
# [186]	test-mlogloss:2.45043
# [187]	test-mlogloss:2.45038
# [188]	test-mlogloss:2.45015
# [189]	test-mlogloss:2.44998
# [190]	test-mlogloss:2.44969
# [191]	test-mlogloss:2.44935
# [192]	test-mlogloss:2.44930
# [193]	test-mlogloss:2.44957
# [194]	test-mlogloss:2.44967
# [195]	test-mlogloss:2.45001
# [196]	test-mlogloss:2.44992
# [197]	test-mlogloss:2.45009
# [198]	test-mlogloss:2.44989
# [199]	test-mlogloss:2.44995
# [200]	test-mlogloss:2.44966
# [201]	test-mlogloss:2.44951
# [202]	test-mlogloss:2.44960
# Độ chính xác (và các metric) theo từng lớp:
#                   precision    recall  f1-score   support
#
#         Banh beo       0.40      0.28      0.33       129
#     Banh bot loc       0.28      0.12      0.17       144
#         Banh can       0.25      0.23      0.24       149
#        Banh canh       0.20      0.15      0.17       193
#       Banh chung       0.52      0.34      0.41       102
#        Banh cuon       0.30      0.35      0.32       228
#         Banh duc       0.15      0.05      0.08       133
#         Banh gio       0.35      0.30      0.33       129
#        Banh khot       0.32      0.23      0.26       167
#          Banh mi       0.37      0.54      0.44       268
#         Banh pia       0.49      0.48      0.49        89
#         Banh tet       0.44      0.26      0.33       138
# Banh trang nuong       0.39      0.38      0.39       159
#         Banh xeo       0.46      0.57      0.51       235
#       Bun bo Hue       0.22      0.42      0.29       306
#  Bun dau mam tom       0.37      0.43      0.40       184
#          Bun mam       0.26      0.19      0.22       155
#         Bun rieu       0.24      0.35      0.28       231
#   Bun thit nuong       0.24      0.15      0.19       150
#        Ca kho to       0.47      0.43      0.45       136
#        Canh chua       0.32      0.24      0.27       165
#          Cao lau       0.19      0.06      0.09       124
#        Chao long       0.34      0.41      0.37       215
#          Com tam       0.30      0.36      0.33       189
#         Goi cuon       0.34      0.27      0.30       172
#          Hu tieu       0.25      0.28      0.26       197
#         Mi quang       0.24      0.27      0.25       177
#         Nem chua       0.55      0.39      0.46       109
#              Pho       0.31      0.30      0.31       162
#          Xoi xeo       0.42      0.30      0.35       105
#
#         accuracy                           0.32      5040
#        macro avg       0.33      0.31      0.31      5040
#     weighted avg       0.32      0.32      0.31      5040
